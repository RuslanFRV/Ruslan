# %% [markdown]
# # Задание 1_Pandas

# %%
import numpy as np
import pandas as pd

# %%
data = {'Surname': ['Ivanov', 'Petrov', 'Sidorov', 'Ivanova', 'Karpov', 'Hill', 'Boni', 'Mitchell', 'Onio', 'Lavrov'],
        'age': [42, 33, 55, np.nan, 65, 23, 25, np.nan, 27, 37],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = [1,2]

# %% [markdown]
# #### 0. Создать датафрейм.

# %%
df1=pd.DataFrame(data)
df1
# Out:
#     Surname   age  visits priority
# 0    Ivanov  42.0       1      yes
# 1    Petrov  33.0       3      yes
# 2   Sidorov  55.0       2       no
# 3   Ivanova   NaN       3      yes
# 4    Karpov  65.0       2       no
# 5      Hill  23.0       3       no
# 6      Boni  25.0       1       no
# 7  Mitchell   NaN       1      yes
# 8      Onio  27.0       2       no
# 9    Lavrov  37.0       1       no

# %% [markdown]
# #### 1. Вывести информацию о датафрейме.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
# Surname     10 non-null object
# age         8 non-null float64
# visits      10 non-null int64
# priority    10 non-null object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 448.0+ bytes

# %%
df1.describe()
# Out:
#              age     visits
# count   8.000000  10.000000
# mean   38.375000   1.900000
# std    14.994642   0.875595
# min    23.000000   1.000000
# 25%    26.500000   1.000000
# 50%    35.000000   2.000000
# 75%    45.250000   2.750000
# max    65.000000   3.000000

# %% [markdown]
# #### 2. Вернуть первые 3 строки DataFrame `df`.

# %%
df1.head(3)
# Out:
#    Surname   age  visits priority
# 0   Ivanov  42.0       1      yes
# 1   Petrov  33.0       3      yes
# 2  Sidorov  55.0       2       no

# %% [markdown]
# #### 3. Выберите только столбцы 'Surname' и 'age' из DataFrame `df`.

# %%
df1[['Surname','age']]
# Out:
#     Surname   age
# 0    Ivanov  42.0
# 1    Petrov  33.0
# 2   Sidorov  55.0
# 3   Ivanova   NaN
# 4    Karpov  65.0
# 5      Hill  23.0
# 6      Boni  25.0
# 7  Mitchell   NaN
# 8      Onio  27.0
# 9    Lavrov  37.0

# %% [markdown]
# #### 4. Выберите данные в строках `[3, 4, 8]` * и * в столбцах `['Surname', 'age']`.

# %%
df1.loc[[3,4,8],['Surname', 'age']]
# Out:
#    Surname   age
# 3  Ivanova   NaN
# 4   Karpov  65.0
# 8     Onio  27.0

# %% [markdown]
# #### 5. Выберите строки где количество посещений банка больше 3.

# %%
a=df1['visits'] > 3
df1.loc[a]
# Out:
# Empty DataFrame
# Columns: [Surname, age, visits, priority]
# Index: []

# %% [markdown]
# #### 6. Выберите строки, в которых отсутствует возраст.

# %%
b=df1['age'].isnull()
df1.loc[b]
# Out:
#     Surname  age  visits priority
# 3   Ivanova  NaN       3      yes
# 7  Mitchell  NaN       1      yes

# %% [markdown]
# #### 7. Выберите строки, в которых клиент был больше 2х раз в банке * и * возраст составляет более 30 лет.

# %%
c=df1['visits']>2 
d=df1['age']>30
df1.loc[c&d]
# Out:
#   Surname   age  visits priority
# 1  Petrov  33.0       3      yes

# %% [markdown]
# #### 8. Выберите строки в которых возраст от 55 до 65 (включительно).

# %%
e=df1['age']>55
f=df1['age']<=65
df1.loc[e&f]
# Out:
#   Surname   age  visits priority
# 4  Karpov  65.0       2       no

# %% [markdown]
# #### 9. Измените возраст в строке '4' на 44.

# %%
df1.loc[4, 'age']=44
df1
# Out:
#     Surname   age  visits priority
# 0    Ivanov  42.0       1      yes
# 1    Petrov  33.0       3      yes
# 2   Sidorov  55.0       2       no
# 3   Ivanova   NaN       3      yes
# 4    Karpov  44.0       2       no
# 5      Hill  23.0       3       no
# 6      Boni  25.0       1       no
# 7  Mitchell   NaN       1      yes
# 8      Onio  27.0       2       no
# 9    Lavrov  37.0       1       no

# %% [markdown]
# #### 10. Рассчитать общее количество всех посещений.

# %%
df1['visits'].sum()
# Out:
# 19

# %% [markdown]
# #### 11. Расчитайте средний возраст клиентов

# %%
df1.age.mean()
# Out:
# 35.75

# %% [markdown]
# #### 12. Добавьте новую строку `k` к `df` со значениями по вашему желанию. Затем удалите ее.

# %%
df1.loc[len(df1)]=['FarizoV','29','0','yes']
df1
# Out:
#      Surname  age visits priority
# 0     Ivanov   42      1      yes
# 1     Petrov   33      3      yes
# 2    Sidorov   55      2       no
# 3    Ivanova  NaN      3      yes
# 4     Karpov   44      2       no
# 5       Hill   23      3       no
# 6       Boni   25      1       no
# 7   Mitchell  NaN      1      yes
# 8       Onio   27      2       no
# 9     Lavrov   37      1       no
# 10   FarizoV   29      0      yes

# %%
import pandas as pd

df2=df1.drop(df1.index[[10]])
df3=pd.DataFrame(df2)
df3
# Out:
#     Surname  age visits priority
# 0    Ivanov   42      1      yes
# 1    Petrov   33      3      yes
# 2   Sidorov   55      2       no
# 3   Ivanova  NaN      3      yes
# 4    Karpov   44      2       no
# 5      Hill   23      3       no
# 6      Boni   25      1       no
# 7  Mitchell  NaN      1      yes
# 8      Onio   27      2       no
# 9    Lavrov   37      1       no

# %% [markdown]
# #### 13. Сортируйте `df` сначала по значениям в 'age' в * возрастающем * порядке, затем по значениям в столбце 'visit' в * возрастающем * порядке.

# %%
df4=df3.sort_values(['age'])
df4
# Out:
#     Surname  age visits priority
# 5      Hill   23      3       no
# 6      Boni   25      1       no
# 8      Onio   27      2       no
# 1    Petrov   33      3      yes
# 9    Lavrov   37      1       no
# 0    Ivanov   42      1      yes
# 4    Karpov   44      2       no
# 2   Sidorov   55      2       no
# 3   Ivanova  NaN      3      yes
# 7  Mitchell  NaN      1      yes

# %%
df5=df3.sort_values(['visits'], ascending=False)
df5
# Out:
#     Surname  age visits priority
# 1    Petrov   33      3      yes
# 3   Ivanova  NaN      3      yes
# 5      Hill   23      3       no
# 2   Sidorov   55      2       no
# 4    Karpov   44      2       no
# 8      Onio   27      2       no
# 0    Ivanov   42      1      yes
# 6      Boni   25      1       no
# 7  Mitchell  NaN      1      yes
# 9    Lavrov   37      1       no

# %% [markdown]
# #### 14. В столбце приоритет замените значения на `Yes` и `No`

# %%
df3.loc[df3['priority'] == 'no','priority'] = 'yes'
df3
# Out:
#     Surname  age visits priority
# 0    Ivanov   42      1      yes
# 1    Petrov   33      3      yes
# 2   Sidorov   55      2      yes
# 3   Ivanova  NaN      3      yes
# 4    Karpov   44      2      yes
# 5      Hill   23      3      yes
# 6      Boni   25      1      yes
# 7  Mitchell  NaN      1      yes
# 8      Onio   27      2      yes
# 9    Lavrov   37      1      yes

# %%
df3.loc[df3['priority'] == 'yes','priority'] = 'no'
df3
# Out:
#     Surname  age visits priority
# 0    Ivanov   42      1       no
# 1    Petrov   33      3       no
# 2   Sidorov   55      2       no
# 3   Ivanova  NaN      3       no
# 4    Karpov   44      2       no
# 5      Hill   23      3       no
# 6      Boni   25      1       no
# 7  Mitchell  NaN      1       no
# 8      Onio   27      2       no
# 9    Lavrov   37      1       no

# %% [markdown]
# #### 15. Предположим, у вас есть DataFrame с 10 столбцами действительных чисел, например:
#
# ```python
# df = pd.DataFrame (np.random.random (size = (5, 10)), columns = список ('abcdefghij'))
# ```
# #### Какой столбец имеет наименьшую сумму? Найдите метку этого столбца.

# %%
import numpy as np
df = pd.DataFrame (np.random.random (size = (5, 10)), columns = list('abcdefghij'))
df
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.771855  0.064572  0.766824  0.980388  0.813047  0.839320  0.420914
# 1  0.412049  0.598619  0.434793  0.138477  0.344435  0.556676  0.532102
# 2  0.480849  0.202446  0.715690  0.039125  0.800990  0.998441  0.799046
# 3  0.866097  0.988512  0.052335  0.530042  0.560171  0.752535  0.562585
# 4  0.208806  0.552526  0.002126  0.954037  0.574477  0.272102  0.776808
#
#           h         i         j
# 0  0.523808  0.300996  0.857449
# 1  0.770652  0.718264  0.625931
# 2  0.659849  0.832964  0.343266
# 3  0.271619  0.620221  0.413905
# 4  0.308015  0.097580  0.173227

# %%
a=df.sum()
pd.DataFrame(a)
# Out:
#           0
# a  2.739656
# b  2.406675
# c  1.971769
# d  2.642070
# e  3.093120
# f  3.419074
# g  3.091456
# h  2.533944
# i  2.570025
# j  2.413777

# %%
g=a.min()
g
# Out:
# 1.971768679908985

# %%
c=pd.DataFrame(a)
b=a.min()

for i in range(len(a)):
    if b == a[i]:
        print(i)
        break
# Out:
# 2

# %%
pd.DataFrame(a).index[9]
# Out:
# 'j'

# %% [markdown]
# #### 16. Замените все пропущенные значения, на среднее по столбцу
# ```python
# df = pd.DataFrame({'group': list('aabbabbbabab'),
#                        'value': [1, 2, 3, np.nan, 2, 3,
#                                  np.nan, 1, 7, 3, np.nan, 8]})
# ```

# %%
df = pd.DataFrame({'group': list('aabbabbbabab'),
                       'value': [1, 2, 3, np.nan, 2, 3, 
                                 np.nan, 1, 7, 3, np.nan, 8]})
pd.DataFrame(df)
# Out:
#    group  value
# 0      a    1.0
# 1      a    2.0
# 2      b    3.0
# 3      b    NaN
# 4      a    2.0
# 5      b    3.0
# 6      b    NaN
# 7      b    1.0
# 8      a    7.0
# 9      b    3.0
# 10     a    NaN
# 11     b    8.0

# %%
df.fillna(df['value'].mean())
# Out:
#    group     value
# 0      a  1.000000
# 1      a  2.000000
# 2      b  3.000000
# 3      b  3.333333
# 4      a  2.000000
# 5      b  3.000000
# 6      b  3.333333
# 7      b  1.000000
# 8      a  7.000000
# 9      b  3.000000
# 10     a  3.333333
# 11     b  8.000000

# %% [markdown]
# #### 17. Создайте два новых столбца, для From и To. Приведите названия городов к нормальному виду.
#
# ```python
# df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm',
#                                'Budapest_PaRis', 'Brussels_londOn'],
#               'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
#               'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
#                    'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
#                                '12. Air France', '"Swiss Air"']})
# ```

# %%
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm', 
                               'Budapest_PaRis', 'Brussels_londOn'],
              'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
              'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
                   'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )', 
                               '12. Air France', '"Swiss Air"']})
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
new_df=df['From_To'].str.split('_', expand=True)
new_df
# Out:
#           0          1
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
new_df.columns=['From','To']
new_df
# Out:
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
final_df=pd.concat([df,new_df],axis=1)
final_df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"
#
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
a=final_df.drop('From_To', axis=1)
pd.DataFrame(a)
# Out:
#    FlightNumber  RecentDelays              Airline      From         To
# 0       10045.0      [23, 47]               KLM(!)    LoNDon      paris
# 1           NaN            []    <Air France> (12)    MAdrid      miLAN
# 2       10065.0  [24, 43, 87]  (British Airways. )    londON  StockhOlm
# 3           NaN          [13]       12. Air France  Budapest      PaRis
# 4       10085.0      [67, 32]          "Swiss Air"  Brussels     londOn

# %% [markdown]
# #### 23. Загрузить свою таблицу данных(из реферата, курсовой, из сайта статистических данных).
#
# Выполните действия с таблицей:
#
# Загрузите таблицу из файла и сохраните ее в переменную df. Используйте функцию read_
#
# Выведите общую информацию по таблице: число строк и столбцов, типы данных в таблице.
#
# Есть ли в таблице пропущенные значения?
#
# Если в таблице есть строки с пропущенными значениями, удалите их.
#
# Сохраните изменения в df.
#
# Выведите на экран описательные статистики по всем количественным переменным в таблице.
#
# Выберите какой-нибудь интересующий вас столбец и проинтерпретируйте описательные статистики по нему (т.е. опишите «обычными» словами, что значат значения типа min, std, 50% и так далее).
#
#
# Переименуйте какие-нибудь столбцы в таблице (хотя бы один, можно несколько) и сохраните изменения в df.
#
# Добавьте новые столбцы.

# %%
df=pd.read_csv(r'C:\Статистика\stat.csv', encoding='cp1251')
df
# Out:
#   Наименование хозяйствующего субъекта Единица измерения        АИ-92(93)  \
# 0                ООО Уренгойтехинком""     руб.коп./литр               46
# 1              ООО Ростнефтегаз-Харп""     руб.коп./литр             45.3
# 2                          ООО Нефто""     руб.коп./литр             47.2
# 3            ООО Газпром нефть-Центр""     руб.коп./литр             45.7
# 4                     Среднее значение     руб.коп./литр  =AVERAGE(C2:C5)
#
#          АИ-95(96) Дизельное топливо
# 0               48                54
# 1             47.5              52.6
# 2             49.9              54.9
# 3             47.8             52.65
# 4  =AVERAGE(D2:D5)   =AVERAGE(E2:E5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
# Наименование хозяйствующего субъекта    5 non-null object
# Единица измерения                       5 non-null object
# АИ-92(93)                               5 non-null object
# АИ-95(96)                               5 non-null object
# Дизельное топливо                       5 non-null object
# dtypes: object(5)
# memory usage: 328.0+ bytes

# %%
pd.isnull(df)
# Out:
#    Наименование хозяйствующего субъекта  Единица измерения  АИ-92(93)  \
# 0                                 False              False      False
# 1                                 False              False      False
# 2                                 False              False      False
# 3                                 False              False      False
# 4                                 False              False      False
#
#    АИ-95(96)  Дизельное топливо
# 0      False              False
# 1      False              False
# 2      False              False
# 3      False              False
# 4      False              False

# %%
df.describe(include='all')
# Out:
#        Наименование хозяйствующего субъекта Единица измерения АИ-92(93)  \
# count                                     5                 5         5
# unique                                    5                 1         5
# top                             ООО Нефто""     руб.коп./литр      45.7
# freq                                      1                 5         1
#
#        АИ-95(96) Дизельное топливо
# count          5                 5
# unique         5                 5
# top           48             52.65
# freq           1                 1

# %%
df.rename(columns={'Единица измерения':'в чем измеряется'}, inplace=True)
df.head()
# Out:
#   Наименование хозяйствующего субъекта в чем измеряется        АИ-92(93)  \
# 0                ООО Уренгойтехинком""    руб.коп./литр               46
# 1              ООО Ростнефтегаз-Харп""    руб.коп./литр             45.3
# 2                          ООО Нефто""    руб.коп./литр             47.2
# 3            ООО Газпром нефть-Центр""    руб.коп./литр             45.7
# 4                     Среднее значение    руб.коп./литр  =AVERAGE(C2:C5)
#
#          АИ-95(96) Дизельное топливо
# 0               48                54
# 1             47.5              52.6
# 2             49.9              54.9
# 3             47.8             52.65
# 4  =AVERAGE(D2:D5)   =AVERAGE(E2:E5)

# %%
import random
df['субъект'] = random.randint(0,23)
df.head()
# Out:
#   Наименование хозяйствующего субъекта в чем измеряется        АИ-92(93)  \
# 0                ООО Уренгойтехинком""    руб.коп./литр               46
# 1              ООО Ростнефтегаз-Харп""    руб.коп./литр             45.3
# 2                          ООО Нефто""    руб.коп./литр             47.2
# 3            ООО Газпром нефть-Центр""    руб.коп./литр             45.7
# 4                     Среднее значение    руб.коп./литр  =AVERAGE(C2:C5)
#
#          АИ-95(96) Дизельное топливо  субъект
# 0               48                54       15
# 1             47.5              52.6       15
# 2             49.9              54.9       15
# 3             47.8             52.65       15
# 4  =AVERAGE(D2:D5)   =AVERAGE(E2:E5)       15

# %%
import matplotlib
df['Наименование хозяйствующего субъекта'].hist()

# %% [markdown]
# ссылки на сайты стат данных
#
#
# https://data.gov.ru/taxonomy/term/9/datasets
#
# http://sophist.hse.ru/rstat/

# %% [markdown]
# можно взять данные из задач
#
# https://github.com/hightemp/docNN/blob/b96f37611dd3ebdd5b2269e04582683af74b8340/articles/%D0%9F%D1%80%D0%B8%D0%BC%D0%B5%D0%BD%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B0%D1%88%D0%B8%D0%BD%D0%BD%D0%BE%D0%B3%D0%BE%20%D0%BE%D0%B1%D1%83%D1%87%D0%B5%D0%BD%D0%B8%D1%8F%20%D0%B8%20Data%20Science%20%D0%B2%20%D0%BF%D1%80%D0%BE%D0%BC%D1%8B%D1%88%D0%BB%D0%B5%D0%BD%D0%BD%D0%BE%D1%81%D1%82%D0%B8.md
